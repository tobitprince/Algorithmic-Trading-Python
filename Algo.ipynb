# %% [markdown]
# <a href="https://colab.research.google.com/github/tobitprince/Algorithmic-Trading-Python/blob/main/Algo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2010-01-01", end = "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2010-01-04   7.622500   7.660714   7.585000   7.643214   6.461976  493729600
# 2010-01-05   7.664286   7.699643   7.616071   7.656429   6.473149  601904800
# 2010-01-06   7.656429   7.686786   7.526786   7.534643   6.370187  552160000
# 2010-01-07   7.562500   7.571429   7.466071   7.520714   6.358408  477131200
# 2010-01-08   7.510714   7.571429   7.466429   7.570714   6.400681  447610800
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-24  71.172501  71.222504  70.730003  71.067497  69.054329   48478800
# 2019-12-26  71.205002  72.495003  71.175003  72.477501  70.424393   93121200
# 2019-12-27  72.779999  73.492500  72.029999  72.449997  70.397682  146266000
# 2019-12-30  72.364998  73.172501  71.305000  72.879997  70.815491  144114400
# 2019-12-31  72.482498  73.419998  72.379997  73.412498  71.332909  100805600
#
# [2516 rows x 6 columns]

# %%
ticker = ["AAPL","SPY", "KO"]

# %%
stocks = yf.download(ticker, start= "2010-01-01", end = "2020-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
# Price       Adj Close                             Close             \
# Ticker           AAPL         KO         SPY       AAPL         KO
# Date
# 2010-01-04   6.461976  18.351231   86.860031   7.643214  28.520000
# 2010-01-05   6.473149  18.129242   87.089966   7.656429  28.174999
# 2010-01-06   6.370187  18.122807   87.151283   7.534643  28.165001
# 2010-01-07   6.358408  18.077763   87.519196   7.520714  28.094999
# 2010-01-08   6.400681  17.743170   87.810425   7.570714  27.575001
# ...               ...        ...         ...        ...        ...
# 2019-12-24  69.054329  47.902809  300.706116  71.067497  54.709999
# 2019-12-26  70.424393  48.174232  302.306854  72.477501  55.020000
# 2019-12-27  70.397682  48.463173  302.231873  72.449997  55.349998
# 2019-12-30  70.815491  48.393127  300.565674  72.879997  55.270000
# 2019-12-31  71.332909  48.463173  301.295837  73.412498  55.349998
#
# Price                        High                               Low  \
# ...

# %%
stocks.head(5)
# Out:
# Price      Adj Close                           Close                         \
# Ticker          AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.461976  18.351231  86.860031  7.643214  28.520000  113.330002
# 2010-01-05  6.473149  18.129242  87.089966  7.656429  28.174999  113.629997
# 2010-01-06  6.370187  18.122807  87.151283  7.534643  28.165001  113.709999
# 2010-01-07  6.358408  18.077763  87.519196  7.520714  28.094999  114.190002
# 2010-01-08  6.400681  17.743170  87.810425  7.570714  27.575001  114.570000
#
# Price           High                              Low                         \
# Ticker          AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# ...

# %%
stocks.to_csv("stocksyt.csv")

# %%
stocks= pd.read_csv("stocksyt.csv", header=[0, 1])
stocks
# Out:
#            Price  Adj Close                             Close             \
#           Ticker       AAPL         KO         SPY       AAPL         KO
# 0           Date        NaN        NaN         NaN        NaN        NaN
# 1     2010-01-04   6.461976  18.351231   86.860031   7.643214  28.520000
# 2     2010-01-05   6.473149  18.129242   87.089966   7.656429  28.174999
# 3     2010-01-06   6.370187  18.122807   87.151283   7.534643  28.165001
# 4     2010-01-07   6.358408  18.077763   87.519196   7.520714  28.094999
# ...          ...        ...        ...         ...        ...        ...
# 2512  2019-12-24  69.054329  47.902809  300.706116  71.067497  54.709999
# 2513  2019-12-26  70.424393  48.174232  302.306854  72.477501  55.020000
# 2514  2019-12-27  70.397682  48.463173  302.231873  72.449997  55.349998
# 2515  2019-12-30  70.815491  48.393127  300.565674  72.879997  55.270000
# 2516  2019-12-31  71.332909  48.463173  301.295837  73.412498  55.349998
#
# ...

# %%
stocks= pd.read_csv("stocksyt.csv", header=[0, 1], index_col=[0])
stocks
# Out:
# Price       Adj Close                             Close             \
# Ticker           AAPL         KO         SPY       AAPL         KO
# Date
# 2010-01-04   6.461976  18.351231   86.860031   7.643214  28.520000
# 2010-01-05   6.473149  18.129242   87.089966   7.656429  28.174999
# 2010-01-06   6.370187  18.122807   87.151283   7.534643  28.165001
# 2010-01-07   6.358408  18.077763   87.519196   7.520714  28.094999
# 2010-01-08   6.400681  17.743170   87.810425   7.570714  27.575001
# ...               ...        ...         ...        ...        ...
# 2019-12-24  69.054329  47.902809  300.706116  71.067497  54.709999
# 2019-12-26  70.424393  48.174232  302.306854  72.477501  55.020000
# 2019-12-27  70.397682  48.463173  302.231873  72.449997  55.349998
# 2019-12-30  70.815491  48.393127  300.565674  72.879997  55.270000
# 2019-12-31  71.332909  48.463173  301.295837  73.412498  55.349998
#
# Price                        High                               Low  \
# ...

# %%
stocks= pd.read_csv("stocksyt.csv", header=[0, 1], parse_dates=[0])
stocks
# Out:
# <ipython-input-15-f810b96aa543>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   stocks= pd.read_csv("stocksyt.csv", header=[0, 1], parse_dates=[0])
#            Price  Adj Close                             Close             \
#           Ticker       AAPL         KO         SPY       AAPL         KO
# 0           Date        NaN        NaN         NaN        NaN        NaN
# 1     2010-01-04   6.461976  18.351231   86.860031   7.643214  28.520000
# 2     2010-01-05   6.473149  18.129242   87.089966   7.656429  28.174999
# 3     2010-01-06   6.370187  18.122807   87.151283   7.534643  28.165001
# 4     2010-01-07   6.358408  18.077763   87.519196   7.520714  28.094999
# ...          ...        ...        ...         ...        ...        ...
# 2512  2019-12-24  69.054329  47.902809  300.706116  71.067497  54.709999
# ...

# %%
stocks.columns
# Out:
# MultiIndex([(    'Price', 'Ticker'),
#             ('Adj Close',   'AAPL'),
#             ('Adj Close',     'KO'),
#             ('Adj Close',    'SPY'),
#             (    'Close',   'AAPL'),
#             (    'Close',     'KO'),
#             (    'Close',    'SPY'),
#             (     'High',   'AAPL'),
#             (     'High',     'KO'),
#             (     'High',    'SPY'),
#             (      'Low',   'AAPL'),
#             (      'Low',     'KO'),
#             (      'Low',    'SPY'),
#             (     'Open',   'AAPL'),
#             (     'Open',     'KO'),
#             (     'Open',    'SPY'),
#             (   'Volume',   'AAPL'),
#             (   'Volume',     'KO'),
#             (   'Volume',    'SPY')],
#            )
